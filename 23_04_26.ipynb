# %%
import secrets

p = 23
g = 5

#alice_private = secrets.randbelow(p-1) + 1
#bob_private = secrets.randbelow(p-1) + 1


alice_private = 5
bob_private = 4

alice_public = pow(g, alice_private, p) #pow(base, exp, mod)
bob_public = pow(g, bob_private, p)

alice_shared = pow(bob_public, alice_private, p) #pow(base, exp, mod)
bob_shared = pow(alice_public, bob_private, p)

print("Shared key:", alice_shared) #ks
# Out:
# Shared key: 12

# %%
import secrets

p = 23
g = 5

alice_private = secrets.randbelow(p-1) + 1
bob_private = secrets.randbelow(p-1) + 1


#alice_private = 5
#bob_private = 4

alice_public = pow(g, alice_private, p) #pow(base, exp, mod)
bob_public = pow(g, bob_private, p)

alice_shared = pow(bob_public, alice_private, p) #pow(base, exp, mod)
bob_shared = pow(alice_public, bob_private, p)

print("Shared key:", alice_shared) #ks
# Out:
# Shared key: 8
